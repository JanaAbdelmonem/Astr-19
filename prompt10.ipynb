# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
random_num = np.random.standard_cauchy(1000)

# %%
plt.figure()
plt.hist(random_num, bins=100)

plt.xlabel("Random Number")
plt.ylabel("Frequency")

plt.savefig("random_histogram2.pdf")
plt.show()
